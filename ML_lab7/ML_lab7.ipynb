# %% [markdown]
# #**LABSHEET 7**
# #**Pricipal Component Analysis**
#
# NAME     : Abhinav Pandey
#
# ROLL NO. : AM.EN.U4AIE21088

# %% [markdown]
# # PART A

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # PART B

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # PART B: INBUILT PCA FUNCTION

# %% [markdown]
# ![image.png](data:image/png;base64,...)
